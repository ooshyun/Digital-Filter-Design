# %%
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt

# %%
name_window_list = [ 'barthann', 
   'bartlett',         
   'blackman',        
   'blackmanharris',
   'bohman',
   'boxcar',     
   'chebwin',       
   'cosine',      
   'dpss',     
   'exponential',
   'flattop',
   'gaussian',     
   'general_cosine',
   'general_gaussian',  
   'general_hamming',   
   'hamming',           
   'hann',            
   'hanning',       
   'kaiser',      
   'nuttall',        
   'parzen',         
   'taylor',       
   'triang',         
   'tukey',
]

nsample = 41
name_window = name_window_list[-9] 
window_scipy = signal.get_window(name_window, Nx=nsample, fftbins=True)
print(name_window)

window_scipy.fill(0)
window_scipy[len(window_scipy)//2+1] = 1
# Out:
# hamming

# %%
plt.plot(window_scipy)
plt.title(f"{name_window} window")
plt.ylabel("Amplitude")
plt.xlabel("Sample")
plt.show()

# %%
window = window_scipy
fft = np.fft.fft
fftshift = np.fft.fftshift

A = fft(window, 2048) / (len(window)/2.0)
freq = np.linspace(-0.5, 0.5, len(A))
response = 20 * np.log10(np.abs(fftshift(A / abs(A).max())))

plt.plot(freq, response)
plt.axis([-0.5, 0.5, -120, 0])
plt.title("Frequency response of the Bartlett-Hann window")
plt.ylabel("Normalized magnitude [dB]")
plt.xlabel("Normalized frequency [cycles per sample]")
plt.show()
